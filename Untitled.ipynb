# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


movie_data_df = pd.read_csv('all_movie_data.csv')
movie_data_df = movie_data_df.loc[(movie_data_df['tweet_count']>10)]
pd.options.display.max_rows = 999
movie_data_df.reset_index()
movie_data_df
# Out:
#                                      title              genre   release  \
# 3                           #TheEmojiMovie          Adventure  20170728
# 4                      #JustGettingStarted             Comedy  20171208
# 5                                   #Rings             Horror  20170203
# 6                              #TheSnowman  Thriller/Suspense  20171020
# 7                                #Geostorm             Action  20171020
# 8                        #FiftyShadesFreed              Drama  20180209
# 9                       #FiftyShadesDarker              Drama  20170210
# 10                          #FatherFigures             Comedy  20171222
# 11              #TransformersTheLastKnight             Action  20170621
# 12                               #WishUpon             Horror  20170714
# 15                               #TheHouse             Comedy  20170630
# 16                                  #CHiPS             Action  20170324
# ...

# %%
for date in movie_data_df['release']:
    date = str(date)
    year = date[:4]
#     print (year)
    month = date[4:6]
#     print (month)
    ym = year + "-" + month
    print (ym)
# Out:
# 2017-07
# 2017-12
# 2017-02
# 2017-10
# 2017-10
# 2018-02
# 2017-02
# 2017-12
# 2017-06
# 2017-07
# 2017-06
# 2017-03
# 2017-08
# 2017-11
# 2017-08
# 2017-11
# 2018-01
# 2017-05
# 2017-04
# 2017-02
# 2017-06
# 2017-01
# 2017-03
# 2017-06
# 2017-02
# 2018-02
# 2017-05
# 2017-11
# 2017-01
# 2017-09
# 2017-10
# 2017-12
# 2017-09
# 2017-12
# 2017-02
# 2018-01
# 2017-08
# 2017-09
# 2017-01
# 2017-10
# 2017-03
# 2017-06
# 2017-02
# 2017-10
# 2017-11
# 2017-03
# 2017-08
# 2017-02
# 2018-01
# 2017-04
# 2017-03
# 2017-05
# 2018-01
# 2017-03
# 2017-09
# 2017-07
# 2017-09
# 2017-09
# 2017-12
# 2018-02
# 2018-03
# 2017-06
# 2017-11
# 2017-06
# 2017-11
# 2017-07
# 2018-01
# 2018-01
# 2017-12
# 2018-03
# 2017-03
# 2017-03
# 2017-10
# 2017-04
# 2018-03
# 2017-04
# 2017-06
# 2017-12
# 2017-12
# 2017-08
# 2017-05
# 2017-04
# 2017-03
# 2018-01
# 2017-12
# 2017-10
# 2017-07
# 2018-02
# 2017-09
# 2017-10
# 2017-12
# 2017-09
# 2017-03
# 2017-06
# 2017-06
# 2017-01
# 2017-12
# 2017-08
# 2018-02
# 2017-07
# ...

# %%
SampleMovieList = ["#TheEmojiMovie", "#JusticeLeague", "#StarWarsTheLastJedi", "#TheHitmansBodyguard", "#TheLegoNinjagoMovie"]
for index, movie in movie_data_df.iterrows():
    for name in SampleMovieList:
        print (name)
        row = movie['title'].index(name)
        print (row)
# Out:
# #TheEmojiMovie
# 0
# #JusticeLeague
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d55945160a31> in <module>()
#       3     for name in SampleMovieList:
#       4         print (name)
# ----> 5         row = movie['title'].index(name)
#       6         print (row)
#
# ValueError: substring not found

# %%
row = movie_data_df[''].index("#TheEmojiMovie")
print (row)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-968b1273d50e> in <module>()
# ----> 1 row = movie_data_df['title'].index("#TheEmojiMovie")
#       2 print (row)
#
# TypeError: 'Int64Index' object is not callable

# %%
for movie in SampleMovieList:
    row = movie_data_df['title'].index(movie)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-e5580013f06b> in <module>()
#       1 for movie in SampleMovieList:
# ----> 2     row = movie_data_df['title'].index(movie)
#
# TypeError: 'Int64Index' object is not callable
