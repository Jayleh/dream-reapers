# %%
# Dependencies
import json
from pprint import pprint
from datetime import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tweepy
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import sys

# Grab config file
sys.path.insert(0, '..')
from config import (consumer_key, consumer_secret,
                    access_token, access_token_secret)

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser(), 
                 wait_on_rate_limit=False, wait_on_rate_limit_notify=False)

# Initialize Sentiment Analyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Movie csv path
csv_path = '../box_office_data/moviesFinal.csv'

# Read csv
movie_df = pd.read_csv(csv_path)
movie_df
# Out:
#                                      title              genre   release  \
# 0                               #Jìyìdàshi  Thriller/Suspense  20170428
# 1          #TylerPerrysBoo2AMadeaHalloween             Comedy  20171020
# 2                             #Gongfuyujia             Action  20170127
# 3                           #TheEmojiMovie          Adventure  20170728
# 4                      #JustGettingStarted             Comedy  20171208
# 5                                   #Rings             Horror  20170203
# 6                              #TheSnowman  Thriller/Suspense  20171020
# 7                                #Geostorm             Action  20171020
# 8                        #FiftyShadesFreed              Drama  20180209
# 9                       #FiftyShadesDarker              Drama  20170210
# 10                          #FatherFigures             Comedy  20171222
# 11              #TransformersTheLastKnight             Action  20170621
# 12                               #WishUpon             Horror  20170714
# 13            #DiaryofaWimpyKidTheLongHaul          Adventure  20170519
# 14                #TheNutJob2NuttybyNature          Adventure  20170811
# 15                               #TheHouse             Comedy  20170630
# 16                                  #CHiPS             Action  20170324
# 17                           #TheDarkTower            Western  20170804
# 18                          #BitterHarvest              Drama  20170224
# 19                                #TheStar          Adventure  20171117
# 20                       #JabHarryMetSejal             Comedy  20170804
# 21                             #TulipFever              Drama  20170901
# 22                            #DaddysHome2             Comedy  20171110
# 23                              #ProudMary             Action  20180112
# 24                               #Baywatch             Comedy  20170525
# 25                   #TheOttomanLieutenant              Drama  20170310
# 26                              #TheCircle  Thriller/Suspense  20170428
# 27                                #Collide             Action  20170224
# 28                            #AllEyezonMe              Drama  20170616
# 29                              #Sleepless  Thriller/Suspense  20170112
# ..                                     ...                ...       ...
# 123                           #DarkestHour              Drama  20171122
# 124                               #Detroit              Drama  20170728
# 125                          #OnlytheBrave              Drama  20171020
# 126                              #Stronger              Drama  20170922
# 127                         #AMonsterCalls              Drama  20170106
# 128                             #WindRiver  Thriller/Suspense  20170803
# 129                      #JohnWickChapter2             Action  20170210
# 130                    #TheLegoBatmanMovie          Adventure  20170210
# 131                          #ChapterVerse              Drama  20170208
# 132                   #SpiderManHomecoming             Action  20170707
# 133                            #LoganLucky             Comedy  20170818
# 134                           #WonderWoman             Action  20170602
# 135                                #ITonya             Comedy  20171208
# 136                               #ThePost              Drama  20171222
# 137                          #Annihilation  Thriller/Suspense  20180223
# 138                          #ThorRagnarok             Action  20171103
# 139                       #BladeRunner2049  Thriller/Suspense  20171006
# 140              #WarforthePlanetoftheApes             Action  20170714
# 141                   #StarWarsTheLastJedi             Action  20171213
# 142                                 #Logan             Action  20170303
# 143                       #TheShapeofWater              Drama  20171201
# 144                            #BabyDriver  Thriller/Suspense  20170628
# 145                         #PhantomThread              Drama  20171225
# 146  #ThreeBillboardsOutsideEbbingMissouri             Comedy  20171110
# 147                                  #Coco            Musical  20171122
# 148                          #BlackPanther             Action  20180216
# 149                               #Dunkirk             Action  20170721
# 150                              #LadyBird              Drama  20171103
# 151                     #BeautyandtheBeast            Musical  20170317
# 139  1.233623  2.267165  0.371422   21.948023
# 140  1.233623  1.708960  1.060433   42.078534
# 141  1.250484  2.520895  5.859418  125.495007
# 142  1.250484  1.286077  2.002636   76.157514
# 143  1.332802 -0.532318 -0.583604    0.487450
# 144  1.332802 -0.287046  0.013878   61.524453
# 145  1.415617 -0.270131 -0.582141    0.599761
# 146  1.448842 -0.659183 -0.579044    2.316304
# 147  1.448842  2.098012  0.900405   34.377724
# 148  1.465206  2.520895  5.331720  115.651517
# 149  1.514796  1.675129  0.891932   38.649448
# 150  1.548021 -0.693014 -0.577805    3.343767
# 151  1.548021  1.844282  4.532996  121.677431
# 152  1.663565 -0.354708 -0.282795   35.511590
#
# [153 rows x 14 columns]

# %%
# # "Real Person" Filters
# min_tweets = 5
# max_tweets = 10000
# max_followers = 2500
# max_following = 2500
# lang = "en"

# Create list of dictionaries
sentiment = []

for title in movie_df['title']:
    
    # Assign title as search term
    search_term = title
    
    # Create variable for holding the oldest tweet
    oldest_tweet = None

    # List to hold average compound values for each movie
    compound_list = []
    
    try:
    
        # Get all tweets from home feed (for each page specified)
        public_tweets = api.search(search_term, 
                                   count=100, 
                                   lang='en', 
                                   result_type="recent", 
                                   max_id=oldest_tweet)

        # Loop through all tweets
        for tweet in public_tweets['statuses']:
               
            # Use filters to check if user meets conditions
            # if (tweet["user"]["followers_count"] < max_followers and
                # tweet["user"]["statuses_count"] > min_tweets and
                # tweet["user"]["statuses_count"] < max_tweets and
                # tweet["user"]["friends_count"] < max_following and
                # tweet["user"]["lang"] == lang):
            
            # Grab tweet data
            tweet_text = tweet['text']
            
            # Run Vader Analysis on each tweet
            results = analyzer.polarity_scores(tweet["text"])
            compound = results["compound"]
            
            # Append compound value to list
            compound_list.append(compound)
            
            # Reassign the the oldest tweet (i.e. the max_id)
            oldest_tweet = int(tweet["id_str"])
        
            # Subtract 1 so the previous oldest isn't included
            # in the new search
            oldest_tweet -= 1

        # Store average 
        tweet_dict = {"title": search_term, 
                      "compound": np.mean(compound_list), 
                      "tweet_count": len(compound_list)}
    
        # Append tweet data to sentiment list
        sentiment.append(tweet_dict)

    except Exception as e:
        print(e)
# Out:
# C:\Users\Justin\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\fromnumeric.py:2909: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# C:\Users\Justin\Anaconda3\envs\PythonData\lib\site-packages\numpy\core\_methods.py:80: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Create dataframe
movie_sent_df = pd.DataFrame(sentiment)

# Reorder columns
movie_sent_df = movie_sent_df[["title", "compound", "tweet_count"]]

# Today's date
today = dt.strftime(dt.now(), "%Y-%m-%d")

# Save to csv
# movie_sent_df.to_csv(f'all_movie_data/{today}_all_movie_sent.csv', encoding='utf-8', index=False)
movie_sent_df
# Out:
#                                      title  compound  tweet_count
# 0                               #Jìyìdàshi       NaN            0
# 1          #TylerPerrysBoo2AMadeaHalloween       NaN            0
# 2                             #Gongfuyujia       NaN            0
# 3                           #TheEmojiMovie  0.013807           46
# 4                      #JustGettingStarted  0.272483          100
# 5                                   #Rings  0.226782           96
# 6                              #TheSnowman  0.192430          100
# 7                                #Geostorm -0.024243          100
# 8                        #FiftyShadesFreed  0.316575          100
# 9                       #FiftyShadesDarker  0.148643          100
# 10                          #FatherFigures  0.156814           29
# 11              #TransformersTheLastKnight -0.015874           39
# 12                               #WishUpon  0.164182           22
# 13            #DiaryofaWimpyKidTheLongHaul       NaN            0
# 14                #TheNutJob2NuttybyNature       NaN            0
# 15                               #TheHouse  0.275202          100
# 16                                  #CHiPS  0.136267          100
# 17                           #TheDarkTower -0.056271          100
# 18                          #BitterHarvest  0.359480            5
# 19                                #TheStar  0.098533          100
# 20                       #JabHarryMetSejal  0.229073          100
# 21                             #TulipFever  0.082900            8
# 22                            #DaddysHome2  0.608814          100
# 23                              #ProudMary  0.216396          100
# 24                               #Baywatch  0.427834          100
# 25                   #TheOttomanLieutenant  0.570900            1
# 26                              #TheCircle  0.216097          100
# 27                                #Collide  0.417881          100
# 28                            #AllEyezonMe  0.106063          100
# 29                              #Sleepless  0.128712          100
# ..                                     ...       ...          ...
# 123                           #DarkestHour  0.211052          100
# 124                               #Detroit -0.066467          100
# 125                          #OnlytheBrave  0.630729          100
# 126                              #Stronger  0.116510           68
# 127                         #AMonsterCalls  0.254082           56
# 128                             #WindRiver  0.284947          100
# 129                      #JohnWickChapter2  0.066827           11
# 130                    #TheLegoBatmanMovie -0.107571           17
# 131                          #ChapterVerse       NaN            0
# 132                   #SpiderManHomecoming  0.270954           65
# 133                            #LoganLucky  0.390471           69
# 134                           #WonderWoman  0.366359          100
# 135                                #ITonya  0.286446          100
# 136                               #ThePost  0.255882          100
# 137                          #Annihilation  0.200074          100
# 138                          #ThorRagnarok  0.244778          100
# 139                       #BladeRunner2049  0.304816          100
# 140              #WarforthePlanetoftheApes  0.447866           86
# 141                   #StarWarsTheLastJedi -0.004869          100
# 142                                 #Logan  0.170142          100
# 143                       #TheShapeofWater  0.220222          100
# 144                            #BabyDriver  0.208796          100
# 145                         #PhantomThread  0.182183          100
# 146  #ThreeBillboardsOutsideEbbingMissouri  0.401179          100
# 147                                  #Coco  0.298744          100
# 148                          #BlackPanther  0.094040          100
# 149                               #Dunkirk  0.190934          100
# 150                              #LadyBird  0.261984          100
# 151                     #BeautyandtheBeast  0.235700          100
# 152               #Baahubali2TheConclusion  0.459800            8
#
# [153 rows x 3 columns]

# %%
# Merge dataframes
merged_df = pd.merge(movie_df, movie_sent_df, how="left")

# Save to csv
merged_df.to_csv(f'all_movie_data.csv', encoding='utf-8', index=False)
merged_df
# Out:
#                                      title              genre   release  \
# 0                               #Jìyìdàshi  Thriller/Suspense  20170428
# 1          #TylerPerrysBoo2AMadeaHalloween             Comedy  20171020
# 2                             #Gongfuyujia             Action  20170127
# 3                           #TheEmojiMovie          Adventure  20170728
# 4                      #JustGettingStarted             Comedy  20171208
# 5                                   #Rings             Horror  20170203
# 6                              #TheSnowman  Thriller/Suspense  20171020
# 7                                #Geostorm             Action  20171020
# 8                        #FiftyShadesFreed              Drama  20180209
# 9                       #FiftyShadesDarker              Drama  20170210
# 10                          #FatherFigures             Comedy  20171222
# 11              #TransformersTheLastKnight             Action  20170621
# 12                               #WishUpon             Horror  20170714
# 13            #DiaryofaWimpyKidTheLongHaul          Adventure  20170519
# 14                #TheNutJob2NuttybyNature          Adventure  20170811
# 15                               #TheHouse             Comedy  20170630
# 16                                  #CHiPS             Action  20170324
# 17                           #TheDarkTower            Western  20170804
# 18                          #BitterHarvest              Drama  20170224
# 19                                #TheStar          Adventure  20171117
# 20                       #JabHarryMetSejal             Comedy  20170804
# 21                             #TulipFever              Drama  20170901
# 22                            #DaddysHome2             Comedy  20171110
# 23                              #ProudMary             Action  20180112
# 24                               #Baywatch             Comedy  20170525
# 25                   #TheOttomanLieutenant              Drama  20170310
# 26                              #TheCircle  Thriller/Suspense  20170428
# 27                                #Collide             Action  20170224
# 28                            #AllEyezonMe              Drama  20170616
# 29                              #Sleepless  Thriller/Suspense  20170112
# ..                                     ...                ...       ...
# 123                           #DarkestHour              Drama  20171122
# 124                               #Detroit              Drama  20170728
# 125                          #OnlytheBrave              Drama  20171020
# 126                              #Stronger              Drama  20170922
# 127                         #AMonsterCalls              Drama  20170106
# 128                             #WindRiver  Thriller/Suspense  20170803
# 129                      #JohnWickChapter2             Action  20170210
# 130                    #TheLegoBatmanMovie          Adventure  20170210
# 131                          #ChapterVerse              Drama  20170208
# 132                   #SpiderManHomecoming             Action  20170707
# 133                            #LoganLucky             Comedy  20170818
# 134                           #WonderWoman             Action  20170602
# 135                                #ITonya             Comedy  20171208
# 136                               #ThePost              Drama  20171222
# 137                          #Annihilation  Thriller/Suspense  20180223
# 138                          #ThorRagnarok             Action  20171103
# 139                       #BladeRunner2049  Thriller/Suspense  20171006
# 140              #WarforthePlanetoftheApes             Action  20170714
# 141                   #StarWarsTheLastJedi             Action  20171213
# 142                                 #Logan             Action  20170303
# 143                       #TheShapeofWater              Drama  20171201
# 144                            #BabyDriver  Thriller/Suspense  20170628
# 145                         #PhantomThread              Drama  20171225
# 146  #ThreeBillboardsOutsideEbbingMissouri             Comedy  20171110
# 147                                  #Coco            Musical  20171122
# 148                          #BlackPanther             Action  20180216
# 149                               #Dunkirk             Action  20170721
# 150                              #LadyBird              Drama  20171103
# 151                     #BeautyandtheBeast            Musical  20170317
# 152               #Baahubali2TheConclusion             Action  20170428
#
#          rated  value     budget    opening   domestic   worldwide     ratio  \
# 0            R   0.00   20000000     224942     587470    43326383  0.011247
# 1        PG-13   0.00   20000000   21226953   47319572    47879572  1.061348
# 2           PG   0.00   65000000     111979     362657   254569616  0.001723
# 3           PG  17.00   50000000   24531923   86089513   216807482  0.490638
# 4        PG-13  22.00   22000000    3201459    6069605     6709821  0.145521
# 5        PG-13  25.67   25000000   13002632   27793018    82991460  0.520105
# 6            R  27.00   35000000    3372565    6670765    43232849  0.096359
# 7        PG-13  29.33  100000000   13707376   33700160   220800160  0.137074
# 8            R  29.33   55000000   38560195   98382615   359382615  0.701094
# 9            R  29.67   55000000   46607250  114434010   381081967  0.847405
# 10           R  31.00   25000000    3287451   17501244    20597799  0.131498
# 11       PG-13  31.67  217000000   44680073  130168683   603968683  0.205899
# 12       PG-13  33.00   12000000    5467084   14301505    23477345  0.455590
# 13          PG  34.00   22000000    7126084   20738724    35355942  0.323913
# 14          PG  34.00   40000000    8342311   28370522    58010968  0.208558
# 15           R  34.67   40000000    8724795   25584504    31192743  0.218120
# 16           R  35.00   25000000    7722802   18600152    23190697  0.308912
# 17       PG-13  35.67   60000000   19153698   50701325   113018076  0.319228
# 18           R  35.67   21000000     219357     557241      606162  0.010446
# 19    APPROVED  36.00   20000000    9812674   40847995    62005389  0.490634
# 20         NaN  36.00   16600000    1284740    1284740    11176544  0.077394
# 21           R  36.33   25000000    1158017    2455635     3882453  0.046321
# 22       PG-13  36.33   70000000   29651193  104029443   176154137  0.423588
# 12  -1.262220 -0.659183 -0.428260   42.781110  0.164182           22
# 13  -1.212630 -0.490030 -0.379639   29.929352       NaN            0
# 14  -1.212630 -0.185555 -0.343995   18.769603       NaN            0
# 15  -1.179405 -0.185555 -0.332785   19.781458  0.275202          100
# 16  -1.163041 -0.439284 -0.362151   28.564581  0.136267          100
# 17  -1.129816  0.152752 -0.027141   30.891483 -0.056271          100
# 18  -1.129816 -0.506945 -0.582057   -1.756318  0.359480            5
# 19  -1.113451 -0.523861 -0.300902   46.824254  0.098533          100
# 20  -1.113451 -0.581373 -0.550834    4.942907  0.229073          100
# 21  -1.097087 -0.439284 -0.554547    1.986602  0.082900            8
# 22  -1.097087  0.321905  0.280513   42.144691  0.608814          100
# 23  -1.063862 -0.625353 -0.296612   68.853654  0.216396          100
# 24  -1.063862  0.152752 -0.046186   29.836303  0.427834          100
# 25  -1.047497 -0.185555 -0.584095   -2.026666  0.570900            1
# 26  -1.047497 -0.557691 -0.323719   47.937085  0.216097          100
# 27  -1.030637 -0.368240 -0.544149    2.693730  0.417881          100
# 28  -1.030637 -0.100978  0.186265   57.986147  0.106063          100
# 29  -1.030637 -0.354708 -0.343941   25.740533  0.128712          100
# ..        ...       ...       ...         ...       ...          ...
# 123  0.985675 -0.354708 -0.583357    0.047607  0.211052          100
# 124  0.985675 -0.287046 -0.578223    0.572154 -0.066467          100
# 125  1.002536 -0.219385 -0.412564   15.754510  0.630729          100
# 126  1.018900 -0.354708 -0.541271    4.951785  0.116510           68
# 127  1.018900 -0.134809 -0.587580   -0.219187  0.254082           56
# 128  1.035265 -0.676098 -0.583751    0.660373  0.284947          100
# 129  1.052125 -0.185555  0.303517   77.563912  0.066827           11
# 130  1.052125  0.491058  0.964907   69.727332 -0.107571           17
# 131  1.052125 -0.185555 -0.587527   -0.226701       NaN            0
# 132  1.068490  2.098012  2.841283   75.721928  0.270954           65
# 133  1.101715 -0.371623 -0.365749   26.205615  0.390471           69
# 134  1.118079  1.675129  2.437544   76.502611  0.366359          100
# 135  1.118079 -0.676098 -0.580744    1.681902  0.286446          100
# 136  1.134444 -0.016401 -0.573070    1.023925  0.255882          100
# 137  1.151304  0.068175 -0.264007   20.821619  0.200074          100
# 138  1.167669  2.182589  3.008848   77.559614  0.244778          100
# 139  1.233623  2.267165  0.371422   21.948023  0.304816          100
# 140  1.233623  1.708960  1.060433   42.078534  0.447866           86
# 141  1.250484  2.520895  5.859418  125.495007 -0.004869          100
# 142  1.250484  1.286077  2.002636   76.157514  0.170142          100
# 143  1.332802 -0.532318 -0.583604    0.487450  0.220222          100
# 144  1.332802 -0.287046  0.013878   61.524453  0.208796          100
# 145  1.415617 -0.270131 -0.582141    0.599761  0.182183          100
# 146  1.448842 -0.659183 -0.579044    2.316304  0.401179          100
# 147  1.448842  2.098012  0.900405   34.377724  0.298744          100
# 148  1.465206  2.520895  5.331720  115.651517  0.094040          100
# 149  1.514796  1.675129  0.891932   38.649448  0.190934          100
# 150  1.548021 -0.693014 -0.577805    3.343767  0.261984          100
# 151  1.548021  1.844282  4.532996  121.677431  0.235700          100
# 152  1.663565 -0.354708 -0.282795   35.511590  0.459800            8
#
# [153 rows x 16 columns]
